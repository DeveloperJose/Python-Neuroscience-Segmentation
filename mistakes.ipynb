# %%
import numpy as np
import json
import pathlib
import pickle

# max_iou = d['val_iou']

for fpath in pathlib.Path('/home/jperez/ray_results/hp_sweep1/').glob('*/params.pkl'):
    try:
        with open(fpath) as file:
        #     d = json.load(file)
            d = pickle.load(file)
    except Exception as ex:
        print(f'Could not open {fpath} | {ex}')
# Out:
# Could not open /home/jperez/ray_results/hp_sweep1/DEFAULT_52990_00225_225_decoder_batchnorm=True,decoder_channels_mult=1,decoder_channels_start=2,decoder_pab=128,encoder_name=resne_2022-03-13_03-45-13/params.pkl | 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
# Could not open /home/jperez/ray_results/hp_sweep1/DEFAULT_52990_00367_367_decoder_batchnorm=True,decoder_channels_mult=1,decoder_channels_start=2,decoder_pab=96,encoder_name=resnex_2022-03-13_15-03-48/params.pkl | 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
# Could not open /home/jperez/ray_results/hp_sweep1/DEFAULT_52990_00467_467_decoder_batchnorm=True,decoder_channels_mult=0,decoder_channels_start=3,decoder_pab=64,encoder_name=resnet_2022-03-13_21-17-31/params.pkl | 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
# ...

# %%
d
# Out:
# {'val_loss': 0.01346572008728981,
#  'val_iou': 0.1285,
#  'time_this_iter_s': 66.95437264442444,
#  'should_checkpoint': True,
#  'done': True,
#  'timesteps_total': None,
#  'episodes_total': None,
#  'training_iteration': 1,
#  'trial_id': '52990_00199',
#  'experiment_id': 'b2d48dc1386a4980a213adc70a1bfc2c',
#  'date': '2022-03-12_23-19-04',
#  'timestamp': 1647152344,
#  'time_total_s': 66.95437264442444,
#  'pid': 3915656,
#  'hostname': 'frodo',
#  'node_ip': '129.108.18.90',
#  'config': {'lr': 0.0010305150567930864,
#   'encoder_name': 'resnet18',
#   'encoder_depth': 4,
#   'decoder_batchnorm': False,
#   'decoder_channels_start': 3,
#   'decoder_channels_mult': 1,
#   'decoder_pab': 128,
#   'loss_weight': 0.3895035291887389,
#   'loss_delta': 0.45290354064077487,
#   'loss_gamma': 0.7117212580017442,
#   'loss_act': 'Softmax(dim=1)',
#   'loss_smooth': 0.9814516422629},
#  'time_since_restore': 66.95437264442444,
#  'timesteps_since_restore': 0,
# ...
